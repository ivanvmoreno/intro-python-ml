# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Doctorado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master' 'Secundaria'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Grado' 'Master'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Secundaria' 'Master' 'Master' 'Grado' 'Master' 'Secundaria'
#  'Grado' 'Master' 'Master' 'Secundaria' 'Secundaria' 'Grado' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Grado' 'Master' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Doctorado'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Master' 'Doctorado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Master' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Doctorado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Doctorado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Master' 'Bachillerato' 'Grado'
#  'Secundaria' 'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Doctorado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Secundaria' 'Doctorado'
#  'Bachillerato' 'Doctorado' 'Grado' 'Doctorado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Doctorado' 'Grado'
#  'Doctorado' 'Secundaria' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado'
#  'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Master'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Master' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Doctorado' 'Secundaria'
#  'Master' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Master' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Doctorado'
#  'Secundaria' 'Master' 'Bachillerato' 'Master' 'Grado' 'Master' 'Master'
#  'Master' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Master'
#  'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Bachillerato'
#  'Master' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Master'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Doctorado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Master'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Master' 'Master' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Grado' 'Grado' 'Grado' 'Master' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Master' 'Secundaria' 'Grado' 'Grado' 'Grado' 'Master' 'Master' 'Master'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Master' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Doctorado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Secundaria' 'Master' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Grado'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Master' 'Secundaria'
#  'Master' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Doctorado' 'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np

estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia, color='orange', edgecolor='blue', linewidth=4) 

plt.grid()
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()
